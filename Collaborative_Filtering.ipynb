# %% [markdown]
# Using the MovieLens 1M dataset, I will use models from the SURPRISE package to achieve an RMSE of 0.87 or lower on the test set.

# %%
# !pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357258 sha256=323ceb985b3bcdad408c131acd1067cb1b606c21f44f901ce7821927114da8cc
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# ...

# %%
import pandas as pd
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
import numpy as np

# %%
ratings = pd.read_csv('ratings.csv')

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
data = ratings[['userId', 'movieId', 'rating']]

# %%
reader = Reader(rating_scale=(0.5, 5.0))

# %%
dataset = Dataset.load_from_df(data, reader)

# %%
from surprise import SVD, KNNBasic, BaselineOnly

# %%
algo = {
    'SVD': SVD(),
    'KNNBasic': KNNBasic(),
    'BaselineOnly': BaselineOnly()
}

# %%
results = {}
for name, al in algo.items():
    cv_results = cross_validate(al, dataset, measures=['RMSE'], cv=5, verbose=True)
    results[name] = cv_results
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8661  0.8791  0.8727  0.8724  0.8752  0.8731  0.0042
# Fit time          1.51    1.54    1.53    1.74    1.96    1.66    0.17
# Test time         0.34    0.12    0.28    0.19    0.25    0.23    0.08
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9513  0.9564  0.9542  0.9389  0.9421  0.9486  0.0069
# ...
